# %% [markdown]
# <a href="https://colab.research.google.com/github/MariiaZimokha/DeepLearning.AI/blob/main/Course_1/week1/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ## Define Neural Network

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer="sgd", loss="mean_squared_error")
# sgd - stochastic gradient descent

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=300)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 0s 422ms/step - loss: 1.9921
# Epoch 2/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7110
# Epoch 3/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4870
# Epoch 4/300
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3078
# Epoch 5/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1640
# Epoch 6/300
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0481
# Epoch 7/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9542
# Epoch 8/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8776
# Epoch 9/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8148
# Epoch 10/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7628
# Epoch 11/300
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7194
# Epoch 12/300
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6828
# ...

# %%
print(model.predict([19]))
# Out:
# [[36.73913]]

# %%
print(model.predict([10]))
# Out:
# [[18.886795]]
